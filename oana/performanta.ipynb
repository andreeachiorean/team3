# %% [markdown]
# **Performanta Model**

# %% [markdown]
# **Activation function all Dense layers: Relu - 3 layers
#     Dense(128), ReLU(),
#     Dense(64), ReLU(),
#     Dense(32), ReLU(),**
#
#
# **MAE: 2.03 years**
#
# RMSE - RMSE penalizează mai sever erorile mari, astfel evidențiază instabilitățile modelului și cazurile extreme, spre deosebire de MAE care tratează toate erorile egal
# RMSE: 2.84 years
#
# R2: ce procent din variația speranței de viață este explicat de model
# **R2: 0.871**
#
# Adjusted R2 - Cât de bine explică modelul variabila țintă, raportat la complexitatea lui, Adjusted R² < R², înseamnă că unele feature-uri nu ajută
# Adjusted R2: 0.868
#
# Median AE -  Pentru 50% din observații, greșeala este sub X ani.- eroarea tipică pentru majoritatea observațiilor
# Median AE: 1.50 years
#
# Procentul de predicții care au o eroare mai mică sau egală cu 1 an.
# Within ±1 year: 35.0%
#
# Procentul de predicții cu eroare ≤ 2 ani.
# Within ±2 years: 62.6%
#
# Max Error (abs): 13.65 years
#     Country: China | Year: 2015
#     Actual: 76.10 | Predicted: 89.75 | Signed error: +13.65
#
# **best epoch: 84**

# %% [markdown]
# **Activation function all Dense layers: LeakyReLU - 3 layers
#     Dense(128), ReLU(),
#     Dense(64), ReLU(),
#     Dense(16), ReLU(),**
#
# **MAE: 2.08 years**
#
# RMSE - RMSE penalizează mai sever erorile mari, astfel evidențiază instabilitățile modelului și cazurile extreme, spre deosebire de MAE care tratează toate erorile egal
# RMSE: 3.09 years
#
# R2: ce procent din variația speranței de viață este explicat de model
# **R2: 0.847**
#
# Adjusted R2 - Cât de bine explică modelul variabila țintă, raportat la complexitatea lui, Adjusted R² < R², înseamnă că unele feature-uri nu ajută
# Adjusted R2: 0.843
#
# Median AE -  Pentru 50% din observații, greșeala este sub X ani.- eroarea tipică pentru majoritatea observațiilor
# Median AE: 1.48 years
#
# Procentul de predicții care au o eroare mai mică sau egală cu 1 an.
# Within ±1 year: 35.3%
#
# Procentul de predicții cu eroare ≤ 2 ani.
# Within ±2 years: 63.2%
#
# Max Error (abs): 23.24 years
#     Country: China | Year: 2015
#     Actual: 76.10 | Predicted: 99.34 | Signed error: +23.24
#
# **best epoch: 68**

# %% [markdown]
# **ReLU + ReduceLR**
#
# **MAE: 2.16 years**
#
# RMSE - RMSE penalizează mai sever erorile mari, astfel evidențiază instabilitățile modelului și cazurile extreme, spre deosebire de MAE care tratează toate erorile egal
# RMSE: 3.71 years
#
# R2: ce procent din variația speranței de viață este explicat de model
# **R2: 0.781**
#
# Adjusted R2 - Cât de bine explică modelul variabila țintă, raportat la complexitatea lui, Adjusted R² < R², înseamnă că unele feature-uri nu ajută
# Adjusted R2: 0.774
#
# Median AE -  Pentru 50% din observații, greșeala este sub X ani.- eroarea tipică pentru majoritatea observațiilor
# Median AE: 1.48 years
#
# Procentul de predicții care au o eroare mai mică sau egală cu 1 an.
# Within ±1 year: 35.1%
#
# Procentul de predicții cu eroare ≤ 2 ani.
# Within ±2 years: 63.5%
#
# Max Error (abs): 37.98 years
#     Country: China | Year: 2015
#     Actual: 76.10 | Predicted: 114.08 | Signed error: +37.98
#
# **best epoch: 75**

# %% [markdown]
# **LeakyReLU 0.01 + ReduceLR**
#
# **MAE: 2.09 years**
#
# RMSE - RMSE penalizează mai sever erorile mari, astfel evidențiază instabilitățile modelului și cazurile extreme, spre deosebire de MAE care tratează toate erorile egal
# RMSE: 3.39 years
#
# R2: ce procent din variația speranței de viață este explicat de model
# **R2: 0.817**
#
# Adjusted R2 - Cât de bine explică modelul variabila țintă, raportat la complexitatea lui, Adjusted R² < R², înseamnă că unele feature-uri nu ajută
# Adjusted R2: 0.812
#
# Median AE -  Pentru 50% din observații, greșeala este sub X ani.- eroarea tipică pentru majoritatea observațiilor
# Median AE: 1.44 years
#
# Procentul de predicții care au o eroare mai mică sau egală cu 1 an.
# Within ±1 year: 39.1%
#
# Procentul de predicții cu eroare ≤ 2 ani.
# Within ±2 years: 62.3%
#
# Max Error (abs): 29.98 years
#     Country: China | Year: 2015
#     Actual: 76.10 | Predicted: 106.08 | Signed error: +29.98
#
# **best epoch: 127**

# %% [markdown]
# **ReLu + Dropout 0.1**
#
#
# **MAE: 2.43 years**
#
# RMSE - RMSE penalizează mai sever erorile mari, astfel evidențiază instabilitățile modelului și cazurile extreme, spre deosebire de MAE care tratează toate erorile egal
# RMSE: 3.75 years
#
# R2: ce procent din variația speranței de viață este explicat de model
# **R2: 0.776**
#
# Adjusted R2 - Cât de bine explică modelul variabila țintă, raportat la complexitatea lui, Adjusted R² < R², înseamnă că unele feature-uri nu ajută
# Adjusted R2: 0.770
#
# Median AE -  Pentru 50% din observații, greșeala este sub X ani.- eroarea tipică pentru majoritatea observațiilor
# Median AE: 1.65 years
#
# Procentul de predicții care au o eroare mai mică sau egală cu 1 an.
# Within ±1 year: 30.2%
#
# Procentul de predicții cu eroare ≤ 2 ani.
# Within ±2 years: 57.8%
#
# Max Error (abs): 34.51 years
#     Country: China | Year: 2015
#     Actual: 76.10 | Predicted: 110.61 | Signed error: +34.51
#
# **best epoch: 60**

# %% [markdown]
# **LeakyReLu 0.01 + Dropout 0.1**
#
# **MAE: 2.53 years**
#
# RMSE - RMSE penalizează mai sever erorile mari, astfel evidențiază instabilitățile modelului și cazurile extreme, spre deosebire de MAE care tratează toate erorile egal
# RMSE: 4.01 years
#
# R2: ce procent din variația speranței de viață este explicat de model
# **R2: 0.744**
#
# Adjusted R2 - Cât de bine explică modelul variabila țintă, raportat la complexitatea lui, Adjusted R² < R², înseamnă că unele feature-uri nu ajută
# Adjusted R2: 0.737
#
# Median AE -  Pentru 50% din observații, greșeala este sub X ani.- eroarea tipică pentru majoritatea observațiilor
# Median AE: 1.75 years
#
# Procentul de predicții care au o eroare mai mică sau egală cu 1 an.
# Within ±1 year: 31.0%
#
# Procentul de predicții cu eroare ≤ 2 ani.
# Within ±2 years: 56.1%
#
# Max Error (abs): 34.03 years
#     Country: China | Year: 2015
#     Actual: 76.10 | Predicted: 110.13 | Signed error: +34.03
#
# **best epoch:65**

# %% [markdown]
# **RANDOM SEARCH**

# %% [markdown]
# **LeakyReLu 0.01 + Random Search**

# %% [markdown]
# BEST HYPERPARAMETERS:
#
# units_1: 256
#
# dropout_1: 0.1
#
#
# units_2: 128
#
# dropout_2: 0.0
#
# units_3: 16
#
# lr: 0.00036868501457257746
#
#
# ================ TEST PERFORMANCE ================
#
# **MAE: 2.41 years**
#
# RMSE: 4.03 years
#
# **R2: 0.741**
#
# Adjusted R2: 0.734
#
# Median AE: 1.53 years
#
# Within ±1 year: 34.8%
#
# Within ±2 years: 58.3%
#
# Max Error: 38.97 years
#
# Country: China | Year: 2015

# %% [markdown]
# **ReLu + Random Search**
#
# BEST HYPERPARAMETERS:
#
# units_1: 256
#
# dropout_1: 0.0
#
# units_2: 128
#
# dropout_2: 0.0
#
# units_3: 32
#
# lr: 0.00041970536830072134
#
#
#
# ================ TEST PERFORMANCE ================
#
# **MAE: 2.14 years**
#
# RMSE: 3.04 years
#
# **R2: 0.852**
#
# Adjusted R2: 0.848
#
# Median AE: 1.52 years
#
# Within ±1 year: 35.4%
#
# Within ±2 years: 62.0%
#
# Max Error: 15.40 years
#
# Country: China | Year: 2012

# %% [markdown]
# **XGBOOST + Random Search**

# %% [markdown]
# ================ BEST TRIAL ================
#
# Best val_mae: 1.2967
#
# Best num_boost_round: 514
#
# Best params:
#
#   objective: reg:squarederror
#
#   eval_metric: mae
#
#   seed: 42
#
#   subsample: 0.6
#
#   min_child_weight: 2
#
#   max_depth: 6
#
#   lambda: 1.0
#
#   gamma: 0.0
#
#   eta: 0.05
#
#   colsample_bytree: 0.6
#
#   alpha: 0.0001
#
#
# ----------------Performanta XGBoost RandomSearch (TEST)---------------------
#
# **MAE: 1.45 years**
#
# RMSE: 2.17 years
#
# **R2: 0.925**
#
# Adjusted R2: 0.923
#
# Median AE: 0.95 years
#
# Within ±1 year: 52.5%
#
# Within ±2 years: 77.0%
#
#
# Max Error (abs): 9.87 years
#
#     Country: Portugal | Year: 2014
#
#     Actual: 89.00 | Predicted: 79.13 | Signed error: -9.87

# %% [markdown]
# ![image.png](attachment:image.png)
